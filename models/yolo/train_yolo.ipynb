# %% [markdown]
# ## Train YOLO

# %%
# !nvidia-smi
# Out:
# Wed Mar 25 16:27:49 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.79                 Driver Version: 595.79         CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   56C    P8              3W /   85W |    1161MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")
result = model.train(
    data = r"e:\OneDrive\Desktop\Project II\data\configs\data.yaml",
    epochs = 50,
    imgsz = 640,
    batch = 16,
    device = "0",
    project='runs_yolo11',     
    name='plate_detection'
)
print("done")
# Out:
# Ultralytics 8.4.26  Python-3.13.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
